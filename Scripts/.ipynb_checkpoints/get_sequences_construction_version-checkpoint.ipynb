# %% [markdown]
# # Developing a function to find transcription factor binding sites from differentially expressed genes

# %% [markdown]
# ## Function aim
# Build a command-line python program count the number of transcription factor binding sites (TFBs) from differentially expressed genes

# %% [markdown]
# ## What are transcription factors
# Transcription factors are proteins that regulate the transcription of genes—that is, their copying into RNA, on the way to making a protein.
#
# https://www.khanacademy.org/science/biology/gene-regulation/gene-regulation-in-eukaryotes/a/eukaryotic-transcription-factors

# %% [markdown]
# ## How do transcription factors work?
#
# A typical transcription factor binds to DNA at a certain target sequence. Once it's bound, the transcription factor makes it either harder or easier for RNA polymerase to bind to the promoter of the gene.
#
# Some transcription factors **activate transcription**. For instance, they may help the general transcription factors and/or RNA polymerase bind to the promoter, as shown in the diagram below.

# %%
# @hidden_cell
from IPython.display import display, Image
Image(url = 'https://ka-perseus-images.s3.amazonaws.com/6567f50d30ad3ac65aff1e815caf202b3abd7111.png')
# Out:
# <img src="https://ka-perseus-images.s3.amazonaws.com/6567f50d30ad3ac65aff1e815caf202b3abd7111.png"/>

# %% [markdown]
# Other transcription factors **repress transcription**. This repression can work in a variety of ways. As one example, a repressor may get in the way of the basal transcription factors or RNA polymerase, making it so they can't bind to the promoter or begin transcription.

# %% [markdown]
# ## Binding sites
#
# A typical transcription factor binds to DNA at a certain target sequence (or motif). Once it's bound, the transcription factor makes it either harder or easier for RNA polymerase to bind to the promoter of the gene, and consequently regulates the amount of messenger RNA (mRNA) produced by the gene. Some transcription factors activate transcription, while others repress transcription.
#
# Transcription factor binding sites (TFBS) are often located in the 5’-upstream region of target genes to modulate the rate of gene transcription. DNA binding sites can be thus defined as short DNA sequences (typically 4 to 30 base pairs long) that are specifically bound by one or more DNA-binding proteins or protein complexes.

# %%
# @hidden_cell
Image(url = 'https://ka-perseus-images.s3.amazonaws.com/1ba8fe2b28b3dd5cd79ec75b74982ee87692dc9e.png')
# Out:
# <img src="https://ka-perseus-images.s3.amazonaws.com/1ba8fe2b28b3dd5cd79ec75b74982ee87692dc9e.png"/>

# %% [markdown]
# The flexibility of DNA is what allows transcription factors at distant binding sites to do their job. The DNA loops like cooked spaghetti to bring far-off binding sites and transcription factors close to general transcription factors or "mediator" proteins.
#
# In the cartoon above, an activating transcription factor bound at a far-away site helps RNA polymerase bind to the promoter and start transcribing.

# %% [markdown]
# To find and count TFBS my function should complete the following tasks:
# 1. Find the coordinates of differentially expressed genes or target genes
# 2. Extract the upstream sequences of these target genes
# 3. Find and count transcription factor binding sites (TFBSs) in the extracted sequences

# %% [markdown]
# ### 0. Filter differentially expressed genes by logFC values

# %%
import pandas as pd
import numpy as np
import math

# %%
# Arguments to pass to first function 
filepath = '/Volumes/sam079/RNAseq-POMV/Results/ControlvsPOMV6_ALL.csv'
gene_name_columnid = 'ENTREZID'
threshold = 2
threshold_column_id = 'logFC'

# %%
def filter_DE_genes_names(filepath, columnid, threshold, threshold_column_id):

    genes = pd.read_csv(filepath) # might crash in the office
    genes = genes.dropna()

    if genes[columnid].dtypes == float:
        genes = genes.astype({columnid:int})
        genes = genes.astype({columnid:str})
        pass
    elif genes[columnid].dtypes == int:
        genes = genes.astype({columnid:str})
    else:
        print("gene names are strings, great!")


    DEgenes = genes.loc[(genes[threshold_column_id] >= threshold) | (genes[threshold_column_id] <= -threshold)]
    DEgenes = DEgenes[[gene_name_columnid]]

    return DEgenes

print(DEgenes)
# Out:
#         ENTREZID
# 195    100380312
# 297    100286653
# 355    106607818
# 374    100136513
# 476    100195251
# 484    106560450
# 522    100302577
# 537    100195148
# 603    100196303
# 632    106586518
# 648    106580888
# 729    106612490
# 747    100306782
# 851    100380724
# 956    100337625
# 1050   100196244
# 1078   100136541
# 1083   100136587
# 1089   100194553
# 1106   100194720
# 1107   100194722
# 1125   100196683
# 1237   106560422
# 1285   106560850
# 1304   106561065
# 1323   106561186
# 1339   106561321
# 1362   106561470
# 1363   106561472
# 1375   106561504
# ...          ...
# 9143   106610285
# 9144   106610286
# 9145   106610287
# 9146   106610288
# 9206   106610637
# 9271   106610967
# 9319   106611246
# 9462   106611944
# 9539   106612344
# 9557   106612527
# 9692   106613461
# 9702   106613521
# 9704   106613533
# 9717   106613622
# 9731   106613674
# 9747   106613747
# 9942   100194889
# 9943   100136920
# 10063  100196022
# 10397  100196087
# 10428  100196194
# 10573  100196256
# 10682  106602560
# 10728  106586517
# 10736  106587588
# 10756  100380557
# 10780  100196351
# 10819  100196201
# 10894  100196425
# 10942  106613932
#
# [302 rows x 1 columns]

# %% [markdown]
# ### 1. Find the coordinates of differentially expressed genes or target genes
#
# https://www.toptal.com/python/comprehensive-introduction-your-genome-scipy

# %%
col_names = ['seqid', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase', 'attributes']

# %%
df = pd.read_csv('/Users/sam079/Documents/2018_Transcription_factors/Data/GCF_000233375.1_ICSASG_v2_genomic.gff', 
                         sep='\t', comment='#', low_memory=False,
                         header=None, names=col_names)

# %%
df.seqid.unique()
# Out:
# array(['NC_027300.1', 'NC_027301.1', 'NC_027302.1', ..., 'NW_012498597.1',
#        'NW_012561447.1', 'NC_001960.1'], dtype=object)

# %%
df.type.value_counts()
# Out:
# exon                     1313909
# CDS                      1155790
# region                    232155
# mRNA                       97746
# gene                       79030
# cDNA_match                 41529
# tRNA                       23676
# lnc_RNA                     9435
# transcript                  2603
# pseudogene                  2556
# V_gene_segment               144
# C_gene_segment                38
# rRNA                           2
# D_loop                         1
# origin_of_replication          1
# Name: type, dtype: int64

# %%
bestref = df[df.source.isin(['BestRefSeq'])]
bestref.sample(20)
# Out:
#                   seqid      source  type     start       end score strand  \
# 765926      NC_027308.1  BestRefSeq   CDS  17016238  17016423     .      -
# 820820      NC_027308.1  BestRefSeq  exon  66053376  66054575     .      -
# 2170389     NC_027321.1  BestRefSeq  exon  51124260  51124558     .      -
# 453264      NC_027303.1  BestRefSeq   CDS  48241592  48241753     .      -
# 2125571     NC_027321.1  BestRefSeq  exon  17220330  17220397     .      +
# 2204442     NC_027322.1  BestRefSeq   CDS  22692679  22692743     .      +
# 2584578  NW_012341938.1  BestRefSeq  exon     10281     10378     .      -
# 1499991     NC_027314.1  BestRefSeq  exon  17399415  17399543     .      +
# 766023      NC_027308.1  BestRefSeq  exon  17068049  17068125     .      -
# 1176020     NC_027311.1  BestRefSeq   CDS  42141299  42141371     .      +
# 1507374     NC_027314.1  BestRefSeq  gene  25578043  25580305     .      +
# 95814       NC_027300.1  BestRefSeq  exon  81893963  81894084     .      +
# 1424837     NC_027313.1  BestRefSeq   CDS  33759762  33759871     .      -
# 1837384     NC_027317.1  BestRefSeq  exon  61941199  61941304     .      -
# 2486355     NC_027327.1  BestRefSeq  exon   6711070   6711350     .      -
# 1231683     NC_027311.1  BestRefSeq   CDS  78150112  78150268     .      -
# 1746011     NC_027316.1  BestRefSeq   CDS  39630370  39630605     .      +
# 66541       NC_027300.1  BestRefSeq   CDS  54651402  54651514     .      +
# 671471      NC_027306.1  BestRefSeq   CDS   5296748   5296890     .      +
# 804720      NC_027308.1  BestRefSeq  mRNA  48043936  48127143     .      -
#
#         phase                                         attributes
# 765926      2  ID=cds28891;Parent=rna33150;Dbxref=GeneID:1001...
# 820820      .  ID=id398971;Parent=rna35258;Dbxref=GeneID:1001...
# 2170389     .  ID=id1057465;Parent=rna87789;Dbxref=GeneID:100...
# 453264      2  ID=cds16500;Parent=rna18890;Dbxref=GeneID:1001...
# 2125571     .  ID=id1035226;Parent=rna86112;Dbxref=GeneID:100...
# 2204442     2  ID=cds78518;Parent=rna89039;Dbxref=GeneID:1001...
# 2584578     .  ID=id1265106;Parent=rna104255;Dbxref=GeneID:10...
# 1499991     .  ID=id729124;Parent=rna61976;Dbxref=GeneID:1001...
# 766023      .  ID=id372042;Parent=rna33154;Dbxref=GeneID:1001...
# 1176020     0  ID=cds43438;Parent=rna49449;Dbxref=GeneID:1001...
# 1507374     .  ID=gene32389;Dbxref=GeneID:100196381;Name=id2;...
# 95814       .  ID=id48334;Parent=rna3384;Dbxref=GeneID:100380...
# 1424837     1  ID=cds51692;Parent=rna58763;Dbxref=GeneID:1003...
# 1837384     .  ID=id893912;Parent=rna75400;Dbxref=GeneID:1001...
# 2486355     .  ID=id1211385;Parent=rna99795;Dbxref=GeneID:100...
# 1231683     1  ID=cds45223;Parent=rna51435;Dbxref=GeneID:1001...
# 1746011     0  ID=cds63309;Parent=rna71833;Dbxref=GeneID:1003...
# 66541       2  ID=cds2129;Parent=rna2391;Dbxref=GeneID:100196...
# 671471      2  ID=cds25221;Parent=rna28925;Dbxref=GeneID:1003...
# 804720      .  ID=rna34505;Parent=gene18436;Dbxref=GeneID:100...

# %%
CDS = bestref[bestref.type == 'CDS']

# %%
CDS = CDS.copy()

# %%
CDS.sample(10).attributes.values
# Out:
# array(['ID=cds52243;Parent=rna59369;Dbxref=GeneID:100380835,Genbank:NP_001167428.1;Name=NP_001167428.1;Note=The RefSeq protein aligns at 85%25 coverage compared to this genomic sequence;exception=annotated by transcript or proteomic data;gbkey=CDS;gene=orc2;inference=similar to AA sequence (same species):RefSeq:NP_001167428.1;partial=true;product=Origin recognition complex subunit 2;protein_id=NP_001167428.1',
#        'ID=cds134;Parent=rna161;Dbxref=GeneID:100196112,Genbank:NP_001134613.1;Name=NP_001134613.1;Note=The RefSeq protein has 1 substitution compared to this genomic sequence;exception=annotated by transcript or proteomic data;gbkey=CDS;gene=cdkn3;inference=similar to AA sequence (same species):RefSeq:NP_001134613.1;product=cyclin-dependent kinase inhibitor 3;protein_id=NP_001134613.1',
#        'ID=cds44351;Parent=rna50430;Dbxref=GeneID:100195178,Genbank:NP_001133679.1;Name=NP_001133679.1;gbkey=CDS;gene=rheb;product=ras homolog enriched in brain;protein_id=NP_001133679.1',
#        'ID=cds90451;Parent=rna103264;Dbxref=GeneID:100196505,Genbank:NP_001135006.1;Name=NP_001135006.1;Note=The RefSeq protein has 1 substitution and aligns at 37%25 coverage compared to this genomic sequence;exception=annotated by transcript or proteomic data;gbkey=CDS;gene=hem4;inference=similar to AA sequence (same species):RefSeq:NP_001135006.1;partial=true;product=Uroporphyrinogen-III synthase;protein_id=NP_001135006.1;start_range=.,3748',
#        'ID=cds30512;Parent=rna34944;Dbxref=GeneID:100286714,Genbank:NP_001140126.1;Name=NP_001140126.1;gbkey=CDS;gene=md19b;product=Mediator of RNA polymerase II transcription subunit 19-B;protein_id=NP_001140126.1',
#        'ID=cds84023;Parent=rna95213;Dbxref=GeneID:100195564,Genbank:NP_001134065.1;Name=NP_001134065.1;gbkey=CDS;gene=prs6a;product=26S protease regulatory subunit 6A;protein_id=NP_001134065.1',
#        'ID=cds75966;Parent=rna86112;Dbxref=GeneID:100380825,Genbank:NP_001167418.1;Name=NP_001167418.1;gbkey=CDS;gene=sc61a;product=transport protein Sec61 subunit alpha;protein_id=NP_001167418.1',
#        'ID=cds63508;Parent=rna72042;Dbxref=GeneID:100380302,Genbank:NP_001167058.1;Name=NP_001167058.1;Note=The RefSeq protein has 1 substitution compared to this genomic sequence;exception=annotated by transcript or proteomic data;gbkey=CDS;gene=s41a2;inference=similar to AA sequence (same species):RefSeq:NP_001167058.1;product=Solute carrier family 41 member 2;protein_id=NP_001167058.1',
#        'ID=cds49295;Parent=rna56104;Dbxref=GeneID:100380312,Genbank:NP_001167068.1;Name=NP_001167068.1;gbkey=CDS;gene=bmp1;product=Bone morphogenetic protein 1 precursor;protein_id=NP_001167068.1',
#        'ID=cds23244;Parent=rna26565;Dbxref=GeneID:100195993,Genbank:NP_001134494.1;Name=NP_001134494.1;gbkey=CDS;gene=stx1b;product=Syntaxin-1B;protein_id=NP_001134494.1'],
#       dtype=object)

# %%
import re


RE_GENE_NAME = re.compile(r'GeneID:(?P<ENTREZID>[0-9]+)')

def extract_gene_name(attributes_str):
    res = RE_GENE_NAME.search(attributes_str)
    return res.group('ENTREZID')


CDS['ENTREZID'] = CDS.attributes.apply(extract_gene_name)

# %%
RE_DESC = re.compile('product=(?P<desc>.+?);')
def extract_description(attributes_str):
    res = RE_DESC.search(attributes_str)
    if res is None:
        return ''
    else:
        return res.group('desc')


CDS['desc'] = CDS.attributes.apply(extract_description)

# %%
CDS.drop('attributes', axis=1, inplace=True)
CDS
# Out:
#                   seqid      source type    start      end score strand phase  \
# 497         NC_027300.1  BestRefSeq  CDS  1342527  1342649     .      +     0
# 498         NC_027300.1  BestRefSeq  CDS  1342922  1343099     .      +     0
# 499         NC_027300.1  BestRefSeq  CDS  1343567  1344243     .      +     2
# 500         NC_027300.1  BestRefSeq  CDS  1345061  1345903     .      +     0
# 2020        NC_027300.1  BestRefSeq  CDS  3499221  3499242     .      -     0
# 2021        NC_027300.1  BestRefSeq  CDS  3498755  3498917     .      -     2
# 2022        NC_027300.1  BestRefSeq  CDS  3498083  3498174     .      -     1
# 2023        NC_027300.1  BestRefSeq  CDS  3496072  3496154     .      -     2
# 2024        NC_027300.1  BestRefSeq  CDS  3495610  3495718     .      -     0
# 2025        NC_027300.1  BestRefSeq  CDS  3494733  3494851     .      -     2
# 2026        NC_027300.1  BestRefSeq  CDS  3494529  3494556     .      -     0
# 2027        NC_027300.1  BestRefSeq  CDS  3494166  3494299     .      -     2
# 2884        NC_027300.1  BestRefSeq  CDS  4470999  4471078     .      +     0
# 2885        NC_027300.1  BestRefSeq  CDS  4471219  4471319     .      +     1
# 2886        NC_027300.1  BestRefSeq  CDS  4471627  4471849     .      +     2
# 2887        NC_027300.1  BestRefSeq  CDS  4472038  4472069     .      +     1
# 2888        NC_027300.1  BestRefSeq  CDS  4472165  4472268     .      +     2
# 2889        NC_027300.1  BestRefSeq  CDS  4472475  4472561     .      +     0
# 2923        NC_027300.1  BestRefSeq  CDS  4489206  4489286     .      -     0
# 2924        NC_027300.1  BestRefSeq  CDS  4485054  4485122     .      -     0
# 2925        NC_027300.1  BestRefSeq  CDS  4479261  4479373     .      -     0
# 2926        NC_027300.1  BestRefSeq  CDS  4476905  4477048     .      -     1
# 2927        NC_027300.1  BestRefSeq  CDS  4474465  4474492     .      -     1
# 2942        NC_027300.1  BestRefSeq  CDS  4497699  4497701     .      -     0
# 2943        NC_027300.1  BestRefSeq  CDS  4496493  4496589     .      -     0
# 2944        NC_027300.1  BestRefSeq  CDS  4495614  4495663     .      -     2
# 2945        NC_027300.1  BestRefSeq  CDS  4495112  4495161     .      -     0
# 2946        NC_027300.1  BestRefSeq  CDS  4494251  4494333     .      -     1
# 2947        NC_027300.1  BestRefSeq  CDS  4493618  4493691     .      -     2
# 2948        NC_027300.1  BestRefSeq  CDS  4493337  4493408     .      -     0
# ...                 ...         ...  ...      ...      ...   ...    ...   ...
# 2947869  NW_012352538.1  BestRefSeq  CDS     2607     2703     .      +     2
# 2947870  NW_012352538.1  BestRefSeq  CDS     4852     5005     .      +     1
# 2950649  NW_012351257.1  BestRefSeq  CDS     6862     7011     .      -     0
# 2950650  NW_012351257.1  BestRefSeq  CDS     6640     6728     .      -     0
# 2951814  NW_012352239.1  BestRefSeq  CDS     9154     9156     .      -     1
# 2951815  NW_012352239.1  BestRefSeq  CDS     9047     9151     .      -     1
# 2951816  NW_012352239.1  BestRefSeq  CDS     8689     8813     .      -     1
# 2951817  NW_012352239.1  BestRefSeq  CDS     7896     7984     .      -     2
# 2951818  NW_012352239.1  BestRefSeq  CDS     7419     7521     .      -     0
# 2951819  NW_012352239.1  BestRefSeq  CDS     7251     7330     .      -     2
# 2951820  NW_012352239.1  BestRefSeq  CDS     1467     1579     .      -     0
# 2951821  NW_012352239.1  BestRefSeq  CDS     1218     1322     .      -     1
# 2952488  NW_012351047.1  BestRefSeq  CDS     5642     5702     .      +     1
# 2952489  NW_012351047.1  BestRefSeq  CDS     6200     6250     .      +     0
# 2952490  NW_012351047.1  BestRefSeq  CDS     6685     6777     .      +     0
# 2952491  NW_012351047.1  BestRefSeq  CDS     7497     7688     .      +     0
# 2953845  NW_012375620.1  BestRefSeq  CDS     1020     1176     .      +     0
# 2954909  NW_012391486.1  BestRefSeq  CDS      673      780     .      +     0
# 2954910  NW_012391486.1  BestRefSeq  CDS     1142     1366     .      +     0
# 2954911  NW_012391486.1  BestRefSeq  CDS     1368     1375     .      +     0
# 2955330  NW_012344191.1  BestRefSeq  CDS     5121     5190     .      +     1
# 2955331  NW_012344191.1  BestRefSeq  CDS     6187     6319     .      +     0
# 2955332  NW_012344191.1  BestRefSeq  CDS    12190    12284     .      +     2
# 2955333  NW_012344191.1  BestRefSeq  CDS    13438    13551     .      +     0
# 2955334  NW_012344191.1  BestRefSeq  CDS    14509    14820     .      +     0
# 2958507  NW_012341884.1  BestRefSeq  CDS    40867    40961     .      -     1
# 2958508  NW_012341884.1  BestRefSeq  CDS    40126    40310     .      -     2
# 2958509  NW_012341884.1  BestRefSeq  CDS    38611    38793     .      -     0
# 2958510  NW_012341884.1  BestRefSeq  CDS    36295    36438     .      -     0
# 2958511  NW_012341884.1  BestRefSeq  CDS    36032    36121     .      -     0
#
#           ENTREZID                                               desc
# 497      100316613          interferon promoter stimulating protein 1
# 498      100316613          interferon promoter stimulating protein 1
# 499      100316613          interferon promoter stimulating protein 1
# 500      100316613          interferon promoter stimulating protein 1
# 2020     100194980  Mediator of RNA polymerase II transcription su...
# 2021     100194980  Mediator of RNA polymerase II transcription su...
# 2022     100194980  Mediator of RNA polymerase II transcription su...
# 2023     100194980  Mediator of RNA polymerase II transcription su...
# 2024     100194980  Mediator of RNA polymerase II transcription su...
# 2025     100194980  Mediator of RNA polymerase II transcription su...
# 2026     100194980  Mediator of RNA polymerase II transcription su...
# 2027     100194980  Mediator of RNA polymerase II transcription su...
# 2884     100196112                cyclin-dependent kinase inhibitor 3
# 2885     100196112                cyclin-dependent kinase inhibitor 3
# 2886     100196112                cyclin-dependent kinase inhibitor 3
# 2887     100196112                cyclin-dependent kinase inhibitor 3
# 2888     100196112                cyclin-dependent kinase inhibitor 3
# 2889     100196112                cyclin-dependent kinase inhibitor 3
# 2923     100286498                          protein cornichon homolog
# 2924     100286498                          protein cornichon homolog
# 2925     100286498                          protein cornichon homolog
# 2926     100286498                          protein cornichon homolog
# 2927     100286498                          protein cornichon homolog
# 2942     100286617                        glia maturation factor beta
# 2943     100286617                        glia maturation factor beta
# 2944     100286617                        glia maturation factor beta
# 2945     100286617                        glia maturation factor beta
# 2946     100286617                        glia maturation factor beta
# 2947     100286617                        glia maturation factor beta
# 2948     100286617                        glia maturation factor beta
# ...            ...                                                ...
# 2947869  100194978                               Glyoxylate reductase
# 2947870  100194978                               Glyoxylate reductase
# 2950649  100195230               Rho-related GTP-binding protein RhoE
# 2950650  100195230               Rho-related GTP-binding protein RhoE
# 2951814  100195290                             Cytosol aminopeptidase
# 2951815  100195290                             Cytosol aminopeptidase
# 2951816  100195290                             Cytosol aminopeptidase
# 2951817  100195290                             Cytosol aminopeptidase
# 2951818  100195290                             Cytosol aminopeptidase
# 2951819  100195290                             Cytosol aminopeptidase
# 2951820  100195290                             Cytosol aminopeptidase
# 2951821  100195290                             Cytosol aminopeptidase
# 2952488  100195452                LAG1 homolog%2C ceramide synthase 2
# 2952489  100195452                LAG1 homolog%2C ceramide synthase 2
# 2952490  100195452                LAG1 homolog%2C ceramide synthase 2
# 2952491  100195452                LAG1 homolog%2C ceramide synthase 2
# 2953845  100194638  general transcription factor IIE%2C polypeptid...
# 2954909  100380294                        Condensin complex subunit 3
# 2954910  100380294                        Condensin complex subunit 3
# 2954911  100380294                        Condensin complex subunit 3
# 2955330  100196742            Multidrug and toxin extrusion protein 1
# 2955331  100196742            Multidrug and toxin extrusion protein 1
# 2955332  100196742            Multidrug and toxin extrusion protein 1
# 2955333  100196742            Multidrug and toxin extrusion protein 1
# 2955334  100196742            Multidrug and toxin extrusion protein 1
# 2958507  100462679                              F-box only protein 32
# 2958508  100462679                              F-box only protein 32
# 2958509  100462679                              F-box only protein 32
# 2958510  100462679                              F-box only protein 32
# 2958511  100462679                              F-box only protein 32
#
# [24897 rows x 10 columns]

# %%
from pyfaidx import Fasta

# %%
genome = Fasta('/Volumes/OSM_CBR_AF_POMV_work/POMV_RNA_seq/Genomes/Salmo_salar/GCF_000233375.1_ICSASG_v2_genomic.fna')

# %%
CDS.head()
# Out:
#             seqid      source type    start      end score strand phase  \
# 497   NC_027300.1  BestRefSeq  CDS  1342527  1342649     .      +     0
# 498   NC_027300.1  BestRefSeq  CDS  1342922  1343099     .      +     0
# 499   NC_027300.1  BestRefSeq  CDS  1343567  1344243     .      +     2
# 500   NC_027300.1  BestRefSeq  CDS  1345061  1345903     .      +     0
# 2020  NC_027300.1  BestRefSeq  CDS  3499221  3499242     .      -     0
#
#        ENTREZID                                               desc
# 497   100316613          interferon promoter stimulating protein 1
# 498   100316613          interferon promoter stimulating protein 1
# 499   100316613          interferon promoter stimulating protein 1
# 500   100316613          interferon promoter stimulating protein 1
# 2020  100194980  Mediator of RNA polymerase II transcription su...

# %%
DEgenes_up = DEgenes_up.astype(str)

# %%
DEgenes_up.dtypes
# Out:
# ENTREZID    object
# dtype: object

# %%
CDS.dtypes
# Out:
# seqid       object
# source      object
# type        object
# start        int64
# end          int64
# score       object
# strand      object
# phase       object
# ENTREZID    object
# desc        object
# dtype: object

# %%
newdf = pd.merge(DEgenes_up, CDS)

# %%
newdf_small = newdf.head()
newdf_small
# Out:
#     ENTREZID        seqid      source type     start       end score strand  \
# 0  100196194  NC_027314.1  BestRefSeq  CDS   3515019   3515088     .      +
# 1  100196194  NC_027314.1  BestRefSeq  CDS   3515273   3515399     .      +
# 2  100196194  NC_027314.1  BestRefSeq  CDS   3515676   3515768     .      +
# 3  100196194  NC_027314.1  BestRefSeq  CDS   3516526   3516538     .      +
# 4  100136513  NC_027308.1  BestRefSeq  CDS  10605995  10606582     .      -
#
#   phase                              desc
# 0     0  Platelet basic protein precursor
# 1     2  Platelet basic protein precursor
# 2     1  Platelet basic protein precursor
# 3     1  Platelet basic protein precursor
# 4     0                thymidylate kinase

# %%
mylist = []
mydict = {}
for index, row in newdf_small.iterrows():
            genes = row['ENTREZID']
            sequences = genome[row['seqid']][row['start'] - 3:row['start']].seq
            mydict[genes] = sequences
            mylist.append(mydict)
            mydict = {}
print(mylist)
# Out:
# [{'100196194': 'CCA'}, {'100196194': 'AGG'}, {'100196194': 'AGT'}, {'100196194': 'AGG'}, {'100136513': 'ACC'}]

# %%
mylist = []
mydict = {}
for index, row in newdf_small.iterrows():
            genes = row['ENTREZID']
            sequences = genome[row['seqid']][row['start']:row['start'] + 3].seq
            mydict[genes] = sequences
            mylist.append(mydict)
            mydict = {}
print(mylist)
# Out:
# [{'100196194': 'TGA'}, {'100196194': 'CCA'}, {'100196194': 'GTC'}, {'100196194': 'AGT'}, {'100136513': 'TGT'}]
